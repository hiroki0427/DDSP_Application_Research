# %% [markdown]
# ## kotomambaを使うための環境構築
# 1.   colabにcondaをインスト―ル
# 2.   kotomambaという名前でpython3.10の仮想環境を構築
#
# ※この方法はkotomambaに特化しており、mambaを用いた音楽生成においてはこれは直接使えない

# %%
# Colabにconda (mamba) をインストールします
# !pip install condacolab
import condacolab
condacolab.install()
# Out:
# ...
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...

# %%
# %%bash
# # 1. "kotomamba" という名前で Python 3.10 の仮想環境を作成
# mamba create -n kotomamba python=3.10 -y
#
# # 2. 作成した kotomamba 環境を有効化
# source activate kotomamba
#
# # 3. リポジトリをクローンして移動
# git clone https://github.com/kotoba-tech/kotomamba.git kotomanba
# cd kotomanba
#
# # 4. Python 3.10 環境で requirements.txt をインストール
# # これでビルドが走らず、Wheelがダウンロードされるはずです
# pip install -r requirements.txt
# Out:
# Process is terminated.

# %%
# 'kotomamba'環境を使ってpythonコマンドを実行し、
# torchがインポートできるか、バージョンはいくつか、GPUは使えるかを確認します

# !mamba run -n kotomamba python -c "import torch; print(f'PyTorch version: {torch.__version__}'); print(f'GPU available: {torch.cuda.is_available()}')"
# Out:
# PyTorch version: 2.1.2+cu118
# GPU available: True
#
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<string>", line 1, in <module>
#   File "/usr/local/envs/kotomamba/lib/python3.10/site-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/envs/kotomamba/lib/python3.10/site-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/envs/kotomamba/lib/python3.10/site-packages/torch/nn/__init__.py", line 1, in <module>
# ...
