# %% [markdown]
# # DDSP IDつきで試験実装
# ### 構成
# 0. ライブラリのインストール
# 1. データのダウンロードと配置
# 2. 前処理
# 3. DDSPDeocderモジュール
# 4. MulchScaleloss
# 5. 実行
#
# ### 使用時の流れ
# 1. データローダーを用いてgoogle driveにデータセットをロードする（初回のみ）
# 2. 各wavファイルに対しあらかじめf0, loudnessを計算しgoogle driveに.ptファイルとして保存する
# 3. 計算を実行する
#
# ### 本モデルの機能
# 1. 任意の楽器の単旋律からf0(t), loudness(t)を抽出（当初librosaだったが、GPUを使って時短するという観点でtorchcrepeを用いる）
# ※今回はz(t)を入力としていない関係で、入力音声の時系列的変化（すなわちトランペットの吹き方の時系列変化）をとらえられない。声を入力とした場合、歌詞の情報は完全に排除された出力が得られる構成になっている
#
# 2. 抽出した情報からGRUを通して各時刻tに対し128次元の隠れ層状態を取得する。（最終出力は無視するため、_で受け取る）
#
# 3. 隠れ状態の情報を線形変換して倍音の構成(B,T,60)、全体音量(B,T,1)、ノイズ(B,T,ノイズの周波数バンド構成)を推定する

# %% [markdown]
# ## 0. ライブラリのインストール

# %%
# 必要なライブラリのインストール
# !pip install torchcrepe librosa numpy matplotlib
# Out:
# Requirement already satisfied: torchcrepe in /usr/local/lib/python3.12/dist-packages (0.0.24)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: resampy in /usr/local/lib/python3.12/dist-packages (from torchcrepe) (0.4.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from torchcrepe) (1.16.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchcrepe) (2.9.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from torchcrepe) (2.9.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torchcrepe) (4.67.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (3.20.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe) (3.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torchcrepe) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torchcrepe) (3.0.3)

# %%
# ==========================================
# 1. ダウンロード不要！ 擬似マルチ楽器データ生成
# ==========================================
import os
import shutil
import glob
import torch
import numpy as np
import librosa

# 1. フォルダを一旦きれいにする (重要！)
OUTPUT_DIR = "data/features"
if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR) # フォルダごと削除
os.makedirs(OUTPUT_DIR, exist_ok=True) # 作り直し

print("フォルダを掃除しました。データを再生成します...")

# 設定
SAMPLE_RATE = 16000
HOP_LENGTH = 64
N_FFT = 2048
OUTPUT_DIR = "data/features"
os.makedirs(OUTPUT_DIR, exist_ok=True)

def generate_synthetic_instrument(inst_name, wave_type, num_samples=5):
    print(f"Generating {inst_name} ({wave_type})...")

    for i in range(num_samples):
        duration = 5.0 # 5秒
        t = np.linspace(0, duration, int(duration * SAMPLE_RATE))

        # ピッチカーブ生成 (ドレミ...と動く)
        # ランダムな動きを加える
        base_freq = np.random.uniform(220, 440)
        freq_movement = np.sin(2 * np.pi * 0.5 * t) * 50 # ゆらぎ
        f0 = base_freq + freq_movement
        f0 = np.clip(f0, 50, 800) # 範囲制限

        # 位相計算
        phases = 2 * np.pi * np.cumsum(f0 / SAMPLE_RATE)

        # 波形生成
        if wave_type == 'sine':
            y = np.sin(phases)
        elif wave_type == 'sawtooth':
            y = (phases % (2 * np.pi)) / np.pi - 1.0
        elif wave_type == 'square':
            y = np.sign(np.sin(phases))

        # エンベロープ (音の強弱)
        env = 0.5 * (1.0 + np.sin(2 * np.pi * 1.0 * t)) # 1Hzでうねる
        y = y * env

        # ノイズを少し足す (リアルにするため)
        y += np.random.normal(0, 0.01, size=y.shape)
        y = y.astype(np.float32)

        # 特徴量抽出
        # f0 (Ground Truthを使えば高速だが、パイプライン確認のため抽出する)
        # 簡易的に計算上のf0を使う
        f0_tensor = torch.from_numpy(f0.astype(np.float32))

        # Loudness
        stft = librosa.stft(y, n_fft=N_FFT, hop_length=HOP_LENGTH)
        loudness = librosa.amplitude_to_db(np.abs(stft).mean(axis=0), ref=np.max).astype(np.float32)

        # サイズ合わせ
        min_len = min(len(f0_tensor), len(loudness))

        # ID割り当て
        if inst_name == 'Flute_Synth': inst_id = 0
        elif inst_name == 'Violin_Synth': inst_id = 1
        elif inst_name == 'Clarinet_Synth': inst_id = 2

        save_path = os.path.join(OUTPUT_DIR, f"{inst_name}_{i}.pt")

        torch.save({
            'audio': torch.from_numpy(y[:min_len*HOP_LENGTH]),
            'f0': f0_tensor[:min_len],
            'loudness': torch.from_numpy(loudness[:min_len]),
            'instrument_id': inst_id
        }, save_path)

# 実行：3種類の楽器を生成
# それぞれ 10個ずつファイルを生成します
generate_synthetic_instrument('Flute_Synth', 'sine', num_samples=10)     # ID=0
generate_synthetic_instrument('Violin_Synth', 'sawtooth', num_samples=10) # ID=1
generate_synthetic_instrument('Clarinet_Synth', 'square', num_samples=10) # ID=2

print("\n完了！ 'data/features' フォルダにデータを作成しました。")
# Out:
# フォルダを掃除しました。データを再生成します...
# Generating Flute_Synth (sine)...
# Generating Violin_Synth (sawtooth)...
# Generating Clarinet_Synth (square)...
#
# 完了！ 'data/features' フォルダにデータを作成しました。

# %%
import torch
import IPython.display as ipd
import numpy as np

def play_pt_file(file_path, sample_rate=16000):
    # 1. ファイルを読み込む
    try:
        data = torch.load(file_path)
    except FileNotFoundError:
        print(f"エラー: ファイルが見つかりません -> {file_path}")
        return

    # 2. 音声データを取り出す
    # 保存時のキー名が 'audio' である前提です
    if 'audio' not in data:
        print("エラー: このptファイルには 'audio' データが含まれていません。")
        print("含まれているキー:", data.keys())
        return

    audio_tensor = data['audio']

    # 3. 再生できる形式（Numpy配列）に変換
    # GPUに乗っている可能性や、形状が [1, T] になっている可能性を考慮
    audio_data = audio_tensor.detach().cpu().numpy().flatten()

    print(f"再生中: {file_path}")

    # 4. プレイヤーを表示
    ipd.display(ipd.Audio(audio_data, rate=sample_rate))

# --- 実行 ---
# 聞きたいファイルのパスを指定してください
# 例: 生成したシンセデータの1つを聞いてみる
play_pt_file("data/features/Violin_Synth_1.pt")
play_pt_file("data/features/Flute_Synth_9.pt")
# Out:
# 再生中: data/features/Violin_Synth_1.pt
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 再生中: data/features/Flute_Synth_9.pt
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## パラメータ設定

# %%
# ==========================================
# 0. 設定 (Hyperparameters)
# ==========================================
SAMPLE_RATE = 16000
N_FFT = 2048
HOP_LENGTH = 64  # 時間分解能を高めるため小さめに設定 (4ms)
BLOCK_SIZE = 512 # 1回の学習で扱うフレーム数

# シンセサイザー設定
N_HARMONICS = 60 # 倍音の数
N_NOISE_BANDS = 65 # ノイズフィルタの周波数バンド数

# モデル設定
HIDDEN_SIZE = 256
N_LAYERS = 1

# --- 設定 ---
OUTPUT_DIR = "data/features"

# %% [markdown]
# ## 1. データのダウンロードとリバーブの除去

# %%
# 1. 必要なライブラリのインストール
# !pip install -U demucs soundfile librosa

import torch
import torchaudio
import librosa
import soundfile as sf
import numpy as np
from demucs.pretrained import get_model
from demucs.apply import apply_model
import os


def separate_with_demucs():
    print("1. モデルをロード中 (htdemucs)...")
    device = "cuda" if torch.cuda.is_available() else "cpu"
    # Demucsの学習済みモデルを取得
    model = get_model('htdemucs').to(device)
    model.eval()

    print("2. 音源を準備中...")
    # 元音源を取得
    filename = librosa.ex('trumpet')
    # Demucsは 44.1kHz で動作するため、ここでリサンプリングして読み込む
    wav, sr = librosa.load(filename, sr=44100, mono=False)

    # モノラルの場合、ステレオ(2ch)に拡張する（モデルの仕様）
    if wav.ndim == 1:
        wav = np.stack([wav, wav]) # [2, T]

    # Tensor化: [Batch, Channels, Time]
    wav_tensor = torch.tensor(wav).unsqueeze(0).to(device)

    print("3. 分離処理を実行中...")
    # モデル適用 (shifts=1 は高速化のため。画質ならshifts=4推奨)
    with torch.no_grad():
        sources = apply_model(model, wav_tensor, shifts=1, split=True, overlap=0.25)

    # sourcesの形状: [Batch, Source_Count, Channels, Time]
    # htdemucsのソース順序: ["drums", "bass", "other", "vocals"]
    # トランペットのような主旋律は "vocals" に入ります
    vocals_idx = model.sources.index('vocals')
    vocals_wav = sources[0, vocals_idx].cpu().numpy() # [Channels, Time]

    # ステレオをモノラルに戻す（平均）
    vocals_mono = vocals_wav.mean(axis=0)

    print("4. 保存中...")
    # 学習用の 16kHz にリサンプリングして保存
    # (soundfileなどを使って手動リサンプリングするのは面倒なので、librosaで再ロード時にやってもいいですが
    #  ここでは簡易的なリサンプリングをして保存します)

    output_path = "dry_trumpet.wav"

    # 44.1k -> 16k へリサンプリング (librosaを使用)
    vocals_resampled = librosa.resample(vocals_mono, orig_sr=44100, target_sr=16000)

    # 保存 (soundfileを使用＝torchaudioのエラー回避)
    sf.write(output_path, vocals_resampled, 16000)

    print(f"成功！ '{output_path}' を作成しました。")

    # 確認再生
    from IPython.display import Audio, display
    display(Audio(output_path, rate=16000))

if __name__ == "__main__":
    separate_with_demucs()
# Out:
# Requirement already satisfied: demucs in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: dora-search in /usr/local/lib/python3.12/dist-packages (from demucs) (0.1.12)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from demucs) (0.8.1)
# Requirement already satisfied: julius>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from demucs) (0.2.7)
# Requirement already satisfied: lameenc>=1.2 in /usr/local/lib/python3.12/dist-packages (from demucs) (1.8.1)
# Requirement already satisfied: openunmix in /usr/local/lib/python3.12/dist-packages (from demucs) (1.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from demucs) (6.0.3)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from demucs) (2.9.0+cu126)
# Requirement already satisfied: torchaudio>=0.8 in /usr/local/lib/python3.12/dist-packages (from demucs) (2.9.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from demucs) (4.67.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.20.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.5.0)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs) (2.3.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs) (1.4.2)
# Requirement already satisfied: submitit in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs) (1.5.4)
# Requirement already satisfied: treetable in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs) (0.2.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.1->demucs) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.1->demucs) (3.0.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->dora-search->demucs) (4.9.3)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit->dora-search->demucs) (3.1.2)
# 1. モデルをロード中 (htdemucs)...
# 2. 音源を準備中...
# 3. 分離処理を実行中...
# 4. 保存中...
# 成功！ 'dry_trumpet.wav' を作成しました。
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 前処理

# %%
# ==========================================
# 1. ダウンロード不要！ 擬似マルチ楽器データ生成
# ==========================================
import os
import torch
import numpy as np
import librosa

# 設定
SAMPLE_RATE = 16000
HOP_LENGTH = 64
N_FFT = 2048
OUTPUT_DIR = "data/features"
os.makedirs(OUTPUT_DIR, exist_ok=True)

def generate_synthetic_instrument(inst_name, wave_type, num_samples=5):
    print(f"Generating {inst_name} ({wave_type})...")

    for i in range(num_samples):
        duration = 5.0 # 5秒
        t = np.linspace(0, duration, int(duration * SAMPLE_RATE))

        # ピッチカーブ生成 (ドレミ...と動く)
        # ランダムな動きを加える
        base_freq = np.random.uniform(220, 440)
        freq_movement = np.sin(2 * np.pi * 0.5 * t) * 50 # ゆらぎ
        f0_high_res = base_freq + freq_movement
        f0_high_res = np.clip(f0_high_res, 50, 800) # 範囲制限

        # 位相計算
        phases = 2 * np.pi * np.cumsum(f0_high_res / SAMPLE_RATE)

        # 波形生成
        if wave_type == 'sine':
            y = np.sin(phases)
        elif wave_type == 'sawtooth':
            y = (phases % (2 * np.pi)) / np.pi - 1.0
        elif wave_type == 'square':
            y = np.sign(np.sin(phases))

        # エンベロープ (音の強弱)
        env = 0.5 * (1.0 + np.sin(2 * np.pi * 1.0 * t)) # 1Hzでうねる
        y = y * env

        # ノイズを少し足す (リアルにするため)
        y += np.random.normal(0, 0.01, size=y.shape)
        y = y.astype(np.float32) # float32は符号部が1ビット、小数点位置が8ビット、残り23ビットが数値情報

        # 特徴量抽出
        # f0 (Ground Truthを使えば高速だが、パイプライン確認のため抽出する)
        # 簡易的に計算上のf0を使う


        # Loudness: 上記で生成したf0について短時間フーリエ変換を行い、各時刻tについて全周波数の値の平均を求めたものをlibrosaライブラリのamplitude_to_db関数に通した出力をloudnessとする
        stft = librosa.stft(y, n_fft=N_FFT, hop_length=HOP_LENGTH)
        loudness = librosa.amplitude_to_db(np.abs(stft).mean(axis=0), ref=np.max).astype(np.float32)

        # 3. f0 (保存用) をダウンサンプリングする！
        # [::HOP_LENGTH] で「64個飛ばし」で取得します。これでLoudnessと同じ解像度になります。
        # (端数処理のため、Loudnessの長さに合わせてカットします)
        f0_frame = f0_high_res[::HOP_LENGTH]
        f0_tensor = torch.from_numpy(f0_frame.astype(np.float32))

        # サイズ合わせ
        min_len = min(len(f0_tensor), len(loudness))

        # ID割り当て
        if inst_name == 'Flute_Synth': inst_id = 0
        elif inst_name == 'Violin_Synth': inst_id = 1
        elif inst_name == 'Clarinet_Synth': inst_id = 2

        save_path = os.path.join(OUTPUT_DIR, f"{inst_name}_{i}.pt")

        torch.save({
            'audio': torch.from_numpy(y[:min_len*HOP_LENGTH]),
            'f0': f0_tensor[:min_len],
            'loudness': torch.from_numpy(loudness[:min_len]),
            'instrument_id': inst_id
        }, save_path)

# 実行：3種類の楽器を生成
# それぞれ 10個ずつファイルを生成します
generate_synthetic_instrument('Flute_Synth', 'sine', num_samples=10)     # ID=0
generate_synthetic_instrument('Violin_Synth', 'sawtooth', num_samples=10) # ID=1
generate_synthetic_instrument('Clarinet_Synth', 'square', num_samples=10) # ID=2

print("\n完了！ 'data/features' フォルダにデータを作成しました。")
# Out:
# Generating Flute_Synth (sine)...
# Generating Violin_Synth (sawtooth)...
# Generating Clarinet_Synth (square)...
#
# 完了！ 'data/features' フォルダにデータを作成しました。

# %% [markdown]
# ## 4. モデル定義(HarmonySynthesizer, Noise_synthesizer, DDSP,LossF)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
# ==========================================
# 1. 成功したコードのシンセサイザー (マスクなし版)
# ==========================================
class HarmonicSynthesizer(nn.Module):
    def __init__(self, sample_rate, hop_length):
        super().__init__()
        self.sample_rate = sample_rate
        self.hop_length = hop_length

    def forward(self, f0, harmonics_dist, global_amp):
        # フレームレートの音声を、16000Hzのサンプリングレートで音声生成するためにUpsampling
        f0_up = F.interpolate(f0.transpose(1, 2), scale_factor=self.hop_length, mode='linear').transpose(1, 2)
        amp_up = F.interpolate(global_amp.transpose(1, 2), scale_factor=self.hop_length, mode='linear').transpose(1, 2)
        harm_up = F.interpolate(harmonics_dist.transpose(1, 2), scale_factor=self.hop_length, mode='linear').transpose(1, 2)

        # Phase Calculation
        harmonic_indices = torch.arange(1, harmonics_dist.shape[-1] + 1, device=f0.device).float()
        frequencies = f0_up * harmonic_indices.view(1, 1, -1)
        phases = 2 * np.pi * torch.cumsum(frequencies / self.sample_rate, dim=1)

        # アンチエイリアシング（ナイキスト周波数（Sampling_rate/2）Hzを超える倍音は0にする）
        nyquist = self.sample_rate / 2.0

        # frequency < nyquist なら 1.0 (通す), そうでなければ 0.0 (消す)
        harmonic_freqs = f0_up * harmonic_indices.view(1, 1, -1)
        anti_aliasing_mask = (harmonic_freqs < nyquist).float()

        # Waveform Generation
        harmonic_waves = torch.sin(phases) * harm_up
        waveform = torch.sum(harmonic_waves, dim=-1, keepdim=True)

        return waveform * amp_up

# FilteredNoiseSynthesizer は前回のままでOK (変更なし)

class FilteredNoiseSynthesizer(nn.Module):
    def __init__(self, block_size, sample_rate):
        super().__init__()
        self.block_size = block_size # 周波数領域での処理単位

    def forward(self, filter_coeffs):
        """
        filter_coeffs: [B, T_frames, N_noise_bands] -> ノイズの周波数特性
        """
        B, T, N = filter_coeffs.shape
        # 時間領域でフィルタ係数をアップサンプリングするのは重いため、
        # 論文では「周波数領域での掛け算」として実装することが多いです。

        # 簡易実装:
        # 1. ホワイトノイズ生成 [B, T_samples]
        T_samples = T * HOP_LENGTH
        noise = torch.rand(B, T_samples, device=filter_coeffs.device) * 2 - 1

        # 2. フィルタ係数をアップサンプリングして適用
        # 本当はLTV(Linear Time Variant)フィルタですが、簡易的に振幅変調として実装します
        # (厳密なDDSPは周波数領域でWindowingをして畳み込みますが、ここでは直感的な実装にします)

        filter_up = F.interpolate(filter_coeffs.transpose(1, 2), scale_factor=HOP_LENGTH, mode='linear').transpose(1, 2)
        # フィルタ係数が周波数バンドごとのゲインを表すと仮定 (簡易化)
        # 本来はここからインパルス応答を作り、畳み込みます。

        # 今回は「学習可能なノイズエンベロープ」として、ノイズ成分全体を1つのバンドとみなして合成します
        # ※厳密な実装にはFFT畳み込みが必要です

        noise_gain = torch.mean(filter_up, dim=-1, keepdim=True) # 平均ゲイン
        return noise.unsqueeze(-1) * noise_gain


# ※クラス定義が必要なら前回のものをそのまま使ってください

# ==========================================
# 2. 成功したコードベースの Multi-Instrument DDSP
# ==========================================
class MultiInstrumentDDSP(nn.Module):
    def __init__(self, n_instruments, embed_dim=64):
        super().__init__()
        self.n_instruments = n_instruments
        self.embed_dim = embed_dim

        # ★追加: 楽器ID用 Embedding
        self.instrument_embedding = nn.Embedding(n_instruments, embed_dim)

        # Input: f0(1) + loudness(1) + embedding(64)
        input_dim = 2 + embed_dim

        # 成功したコードと同じ構造 (MLP -> GRU)
        self.mlp = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU()
        )
        self.gru = nn.GRU(256, HIDDEN_SIZE, num_layers=N_LAYERS, batch_first=True)

        # Output layers
        self.dense_amp = nn.Linear(HIDDEN_SIZE, 1)
        self.dense_harm = nn.Linear(HIDDEN_SIZE, N_HARMONICS)
        self.dense_noise = nn.Linear(HIDDEN_SIZE, N_NOISE_BANDS)

        self.harmonic_synth = HarmonicSynthesizer(SAMPLE_RATE, HOP_LENGTH)
        self.noise_synth = FilteredNoiseSynthesizer(BLOCK_SIZE, SAMPLE_RATE)

    def forward(self, f0_hz, f0_norm, loudness_norm, instrument_id):
        # 1. Embedding処理
        style_emb = self.instrument_embedding(instrument_id)
        T = f0_norm.shape[1]
        style_emb = style_emb.unsqueeze(1).expand(-1, T, -1)

        # 結合
        x = torch.cat([f0_norm, loudness_norm, style_emb], dim=-1)

        # 2. 本体処理 (成功コードと同じ)
        x = self.mlp(x)
        x, _ = self.gru(x)

        # 3. パラメータ射影 (成功コードと同じ exp を使用！)
        # バイアス初期化などの小細工もやめます（初期値のまま）
        amp = torch.exp(self.dense_amp(x))
        harm_dist = F.softmax(self.dense_harm(x), dim=-1)
        #noise_coeffs = torch.exp(self.dense_noise(x))

        # 4. 合成
        audio_harm = self.harmonic_synth(f0_hz, harm_dist, amp)
        #audio_noise = self.noise_synth(noise_coeffs)

        final_audio = audio_harm #+ audio_noise

        # ★重要: tanh は削除します！ 生の波形を返します。
        return final_audio.squeeze(-1)
# ==========================================
# 4. Loss Function (Multi-Scale Spectral Loss)
# ==========================================

def multiscale_spectral_loss(pred, target, fft_sizes=[2048, 1024, 512, 256, 128, 64]):
    loss = 0.0
    for n_fft in fft_sizes:
        hop = n_fft // 4

        # STFT
        pred_stft = torch.stft(pred, n_fft=n_fft, hop_length=hop, window=torch.hann_window(n_fft).to(pred.device), return_complex=True)
        target_stft = torch.stft(target, n_fft=n_fft, hop_length=hop, window=torch.hann_window(n_fft).to(target.device), return_complex=True)

        pred_mag = torch.abs(pred_stft)
        target_mag = torch.abs(target_stft)

        # Linear Loss (L1)
        loss += F.l1_loss(pred_mag, target_mag)

        # Log Loss (L1)
        loss += F.l1_loss(torch.log(pred_mag + 1e-7), torch.log(target_mag + 1e-7))

    return loss

# %% [markdown]
# ## 3. データセットクラスの追加

# %%
# データセットクラスを追加。instrument_idを付与する
import glob
from torch.utils.data import Dataset, DataLoader

# Datasetクラス (globで全ファイルを読み込む)
class SyntheticDataset(Dataset):
    def __init__(self, data_dir, crop_len_sec=4.0, sample_rate=16000, hop_length=64):
        self.files = glob.glob(os.path.join(data_dir, "*.pt"))
        self.crop_len = int(crop_len_sec * sample_rate / hop_length)
        self.hop_length = hop_length
        self.f_min, self.f_max = 0.0, 2000.0
        self.l_min, self.l_max = -120.0, 0.0
        print(f"Dataset Loaded: {len(self.files)} files found.")

    def __len__(self):
        return 1000

    def __getitem__(self, idx):
        path = np.random.choice(self.files)
        data = torch.load(path)

        audio = data['audio'] #サンプリングレート
        f0 = data['f0'] #フレームレート
        loud = data['loudness'] #フレームレート
        inst_id = data['instrument_id'] # 保存されたID (0, 1, 2)

        # Random Crop
        total_frames = len(f0)
        if total_frames > self.crop_len:
            start = np.random.randint(0, total_frames - self.crop_len)
        else:
            start = 0
        end = start + self.crop_len

        f0 = f0[start:end]
        loud = loud[start:end]
        audio_crop = audio[start*self.hop_length : end*self.hop_length]

        # 正規化
        f0_norm = (f0 - self.f_min) / (self.f_max - self.f_min + 1e-7)
        loud_norm = (loud - self.l_min) / (self.l_max - self.l_min + 1e-7)
        loud_norm = torch.clamp(loud_norm, 0.0, 1.0)

        # Padding if needed
        if len(f0) < self.crop_len:
            pad = self.crop_len - len(f0)
            f0 = F.pad(f0, (0, pad))
            f0_norm = F.pad(f0_norm, (0, pad))
            loud_norm = F.pad(loud_norm, (0, pad))
            audio_crop = F.pad(audio_crop, (0, pad * self.hop_length))

        return {
            'f0': f0.unsqueeze(-1),
            'f0_norm': f0_norm.unsqueeze(-1),
            'loudness_norm': loud_norm.unsqueeze(-1),
            'instrument_id': torch.tensor(inst_id, dtype=torch.long),
            'audio': audio_crop
        }

# %% [markdown]
# ## 4. 学習の実行

# %%
# --- 前回のDDSPモデル定義など (省略せずに必要なクラスを再定義) ---
# ※ ここに前回の回答にある「HarmonicSynthesizer」「FilteredNoiseSynthesizer」「DDSP」クラスがある前提です。
#    長くなるため、クラス定義部分は前回のコードをそのまま貼り付けてください。
#    (以下は学習ループのメイン部分のみ記述します)


# ==========================================
# 学習実行
# ==========================================
def train_synthetic():
    dataset = SyntheticDataset(OUTPUT_DIR)
    dataloader = DataLoader(dataset, batch_size=16, shuffle=True)
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    # 楽器は3種類 (Sine, Saw, Square)
    # モデルは前回の「成功したコードベースのMultiInstrumentDDSP」を使用してください
    model = MultiInstrumentDDSP(n_instruments=3, embed_dim=64).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    # ★追加: スケジューラ (Lossが下がらなくなったら学習率を半分にする)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=5)

    print("Synthetic Training Start...")

    for epoch in range(1, 101): # テストなので20エポックで十分
        total_loss = 0
        for i, batch in enumerate(dataloader):
            f0_hz = batch['f0'].to(device)

            f0_norm = batch['f0_norm'].to(device)
            loud_norm = batch['loudness_norm'].to(device)
            inst_id = batch['instrument_id'].to(device)
            target = batch['audio'].to(device)

            optimizer.zero_grad() # 勾配を初期化。初期化しないと、前回のepochでパラメータ更新に使われた勾配が残ってしまい、学習の妨げになってしまう

            # tanhなし、exp使用のモデル
            pred = model(f0_hz, f0_norm, loud_norm, inst_id)
            loss = multiscale_spectral_loss(pred, target)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            total_loss += loss.item()
            avg_loss = total_loss / (i + 1)

            if i % 10 == 0:
                print(f"Epoch {epoch} | Step {i} | Loss: {loss.item():.4f}")

        # エポック全体の平均lossを計算
        avg_loss = total_loss / len(dataloader)
        print(f"=== Epoch {epoch} Finished | Avg Loss: {avg_loss:.4f} ===")

        # スケジューラに報告
        scheduler.step(total_loss)

        # モデルを保存
        torch.save(model.state_dict(), f"ddsp_multi_synth_{epoch}.pth")

    torch.save(model.state_dict(), "ddsp_multi_synth_final.pth")
    print("All training finished. Model saved.")

if __name__ == "__main__":
    train_synthetic()
# Out:
# Dataset Loaded: 30 files found.
# Synthetic Training Start...
# Epoch 1 | Step 0 | Loss: 18.6441
# Epoch 1 | Step 10 | Loss: 14.0611
# Epoch 1 | Step 20 | Loss: 13.2761
# Epoch 1 | Step 30 | Loss: 12.5238
# Epoch 1 | Step 40 | Loss: 11.3567
# Epoch 1 | Step 50 | Loss: 11.5504
# Epoch 1 | Step 60 | Loss: 12.6128
# === Epoch 1 Finished | Avg Loss: 13.4864 ===
# Epoch 2 | Step 0 | Loss: 13.5451
# Epoch 2 | Step 10 | Loss: 11.4019
# Epoch 2 | Step 20 | Loss: 13.3198
# Epoch 2 | Step 30 | Loss: 12.2759
# Epoch 2 | Step 40 | Loss: 12.0009
# Epoch 2 | Step 50 | Loss: 12.4848
# Epoch 2 | Step 60 | Loss: 12.9678
# === Epoch 2 Finished | Avg Loss: 12.4587 ===
# Epoch 3 | Step 0 | Loss: 12.4231
# Epoch 3 | Step 10 | Loss: 11.9657
# Epoch 3 | Step 20 | Loss: 10.9369
# Epoch 3 | Step 30 | Loss: 17.2137
# Epoch 3 | Step 40 | Loss: 25.5087
# Epoch 3 | Step 50 | Loss: 16.1265
# Epoch 3 | Step 60 | Loss: 12.1242
# === Epoch 3 Finished | Avg Loss: 12.4080 ===
# Epoch 4 | Step 0 | Loss: 12.9989
# Epoch 4 | Step 10 | Loss: 11.8716
# Epoch 4 | Step 20 | Loss: 11.6839
# Epoch 4 | Step 30 | Loss: 13.4583
# Epoch 4 | Step 40 | Loss: 9.7322
# Epoch 4 | Step 50 | Loss: 9.0976
# Epoch 4 | Step 60 | Loss: 21.1938
# === Epoch 4 Finished | Avg Loss: 11.6426 ===
# Epoch 5 | Step 0 | Loss: 14.4492
# Epoch 5 | Step 10 | Loss: 11.7620
# Epoch 5 | Step 20 | Loss: 9.3887
# Epoch 5 | Step 30 | Loss: 10.7410
# Epoch 5 | Step 40 | Loss: 9.7061
# Epoch 5 | Step 50 | Loss: 8.8505
# Epoch 5 | Step 60 | Loss: 9.9574
# === Epoch 5 Finished | Avg Loss: 10.2423 ===
# Epoch 6 | Step 0 | Loss: 9.0549
# Epoch 6 | Step 10 | Loss: 10.8846
# Epoch 6 | Step 20 | Loss: 12.5674
# Epoch 6 | Step 30 | Loss: 10.1268
# Epoch 6 | Step 40 | Loss: 8.4964
# Epoch 6 | Step 50 | Loss: 9.7139
# Epoch 6 | Step 60 | Loss: 9.5792
# === Epoch 6 Finished | Avg Loss: 9.9930 ===
# Epoch 7 | Step 0 | Loss: 9.1973
# Epoch 7 | Step 10 | Loss: 8.5732
# Epoch 7 | Step 20 | Loss: 8.8716
# Epoch 7 | Step 30 | Loss: 10.5890
# Epoch 7 | Step 40 | Loss: 7.9787
# Epoch 7 | Step 50 | Loss: 9.7118
# Epoch 7 | Step 60 | Loss: 9.6729
# === Epoch 7 Finished | Avg Loss: 8.9260 ===
# Epoch 8 | Step 0 | Loss: 9.4074
# Epoch 8 | Step 10 | Loss: 8.4014
# Epoch 8 | Step 20 | Loss: 8.1761
# Epoch 8 | Step 30 | Loss: 8.0901
# Epoch 8 | Step 40 | Loss: 8.1487
# Epoch 8 | Step 50 | Loss: 9.1387
# Epoch 8 | Step 60 | Loss: 7.7817
# === Epoch 8 Finished | Avg Loss: 8.2635 ===
# Epoch 9 | Step 0 | Loss: 9.0720
# Epoch 9 | Step 10 | Loss: 7.6456
# Epoch 9 | Step 20 | Loss: 9.2881
# Epoch 9 | Step 30 | Loss: 9.2291
# Epoch 9 | Step 40 | Loss: 7.8554
# Epoch 9 | Step 50 | Loss: 7.7136
# Epoch 9 | Step 60 | Loss: 7.5602
# === Epoch 9 Finished | Avg Loss: 8.4454 ===
# Epoch 10 | Step 0 | Loss: 7.1942
# Epoch 10 | Step 10 | Loss: 8.1736
# Epoch 10 | Step 20 | Loss: 7.9323
# Epoch 10 | Step 30 | Loss: 9.3007
# Epoch 10 | Step 40 | Loss: 7.8263
# Epoch 10 | Step 50 | Loss: 7.3502
# Epoch 10 | Step 60 | Loss: 7.7278
# === Epoch 10 Finished | Avg Loss: 8.0005 ===
# Epoch 11 | Step 0 | Loss: 7.7613
# Epoch 11 | Step 10 | Loss: 7.5615
# Epoch 11 | Step 20 | Loss: 7.7289
# Epoch 11 | Step 30 | Loss: 7.5920
# Epoch 11 | Step 40 | Loss: 7.6577
# Epoch 11 | Step 50 | Loss: 7.5650
# Epoch 11 | Step 60 | Loss: 7.4825
# === Epoch 11 Finished | Avg Loss: 7.5960 ===
# Epoch 12 | Step 0 | Loss: 7.3945
# Epoch 12 | Step 10 | Loss: 7.2277
# Epoch 12 | Step 20 | Loss: 7.5277
# Epoch 12 | Step 30 | Loss: 7.1458
# Epoch 12 | Step 40 | Loss: 7.2954
# Epoch 12 | Step 50 | Loss: 7.1979
# Epoch 12 | Step 60 | Loss: 7.3489
# === Epoch 12 Finished | Avg Loss: 7.5764 ===
# Epoch 13 | Step 0 | Loss: 7.4052
# Epoch 13 | Step 10 | Loss: 7.9395
# Epoch 13 | Step 20 | Loss: 7.3532
# Epoch 13 | Step 30 | Loss: 7.1555
# Epoch 13 | Step 40 | Loss: 7.2567
# Epoch 13 | Step 50 | Loss: 7.1148
# Epoch 13 | Step 60 | Loss: 7.1669
# === Epoch 13 Finished | Avg Loss: 7.4356 ===
# Epoch 14 | Step 0 | Loss: 6.8994
# Epoch 14 | Step 10 | Loss: 7.0874
# Epoch 14 | Step 20 | Loss: 7.1726
# Epoch 14 | Step 30 | Loss: 7.3403
# Epoch 14 | Step 40 | Loss: 8.8033
# Epoch 14 | Step 50 | Loss: 7.2689
# Epoch 14 | Step 60 | Loss: 7.3064
# === Epoch 14 Finished | Avg Loss: 7.2962 ===
# Epoch 15 | Step 0 | Loss: 7.6016
# Epoch 15 | Step 10 | Loss: 7.3977
# Epoch 15 | Step 20 | Loss: 6.9536
# Epoch 15 | Step 30 | Loss: 6.9478
# Epoch 15 | Step 40 | Loss: 6.9056
# Epoch 15 | Step 50 | Loss: 7.0455
# Epoch 15 | Step 60 | Loss: 6.9837
# === Epoch 15 Finished | Avg Loss: 7.1249 ===
# Epoch 16 | Step 0 | Loss: 6.9725
# Epoch 16 | Step 10 | Loss: 6.9027
# Epoch 16 | Step 20 | Loss: 6.9854
# Epoch 16 | Step 30 | Loss: 7.2820
# Epoch 16 | Step 40 | Loss: 7.1505
# Epoch 16 | Step 50 | Loss: 7.4895
# Epoch 16 | Step 60 | Loss: 7.4568
# === Epoch 16 Finished | Avg Loss: 7.1382 ===
# Epoch 17 | Step 0 | Loss: 8.3847
# Epoch 17 | Step 10 | Loss: 7.2590
# Epoch 17 | Step 20 | Loss: 6.7008
# Epoch 17 | Step 30 | Loss: 6.6850
# Epoch 17 | Step 40 | Loss: 6.7124
# Epoch 17 | Step 50 | Loss: 7.1206
# Epoch 17 | Step 60 | Loss: 7.0907
# === Epoch 17 Finished | Avg Loss: 7.0217 ===
# Epoch 18 | Step 0 | Loss: 7.1029
# Epoch 18 | Step 10 | Loss: 7.0815
# Epoch 18 | Step 20 | Loss: 6.6212
# Epoch 18 | Step 30 | Loss: 7.1371
# Epoch 18 | Step 40 | Loss: 7.3850
# Epoch 18 | Step 50 | Loss: 7.0755
# Epoch 18 | Step 60 | Loss: 6.9400
# === Epoch 18 Finished | Avg Loss: 7.0476 ===
# Epoch 19 | Step 0 | Loss: 6.9313
# Epoch 19 | Step 10 | Loss: 6.6937
# Epoch 19 | Step 20 | Loss: 7.0603
# Epoch 19 | Step 30 | Loss: 7.0775
# Epoch 19 | Step 40 | Loss: 6.8576
# Epoch 19 | Step 50 | Loss: 6.7146
# Epoch 19 | Step 60 | Loss: 6.6965
# === Epoch 19 Finished | Avg Loss: 6.8776 ===
# Epoch 20 | Step 0 | Loss: 6.7231
# Epoch 20 | Step 10 | Loss: 7.0072
# Epoch 20 | Step 20 | Loss: 6.8565
# Epoch 20 | Step 30 | Loss: 6.6824
# Epoch 20 | Step 40 | Loss: 6.5349
# Epoch 20 | Step 50 | Loss: 6.5559
# Epoch 20 | Step 60 | Loss: 6.4673
# === Epoch 20 Finished | Avg Loss: 6.6955 ===
# Epoch 21 | Step 0 | Loss: 6.6848
# Epoch 21 | Step 10 | Loss: 6.8041
# Epoch 21 | Step 20 | Loss: 6.5699
# Epoch 21 | Step 30 | Loss: 6.8242
# Epoch 21 | Step 40 | Loss: 6.8272
# Epoch 21 | Step 50 | Loss: 6.7326
# Epoch 21 | Step 60 | Loss: 6.6768
# === Epoch 21 Finished | Avg Loss: 6.7748 ===
# Epoch 22 | Step 0 | Loss: 6.8762
# Epoch 22 | Step 10 | Loss: 6.9229
# Epoch 22 | Step 20 | Loss: 6.7875
# Epoch 22 | Step 30 | Loss: 6.5546
# Epoch 22 | Step 40 | Loss: 6.5297
# Epoch 22 | Step 50 | Loss: 6.9073
# Epoch 22 | Step 60 | Loss: 6.5728
# === Epoch 22 Finished | Avg Loss: 6.7747 ===
# Epoch 23 | Step 0 | Loss: 6.7099
# Epoch 23 | Step 10 | Loss: 6.7493
# Epoch 23 | Step 20 | Loss: 6.7690
# Epoch 23 | Step 30 | Loss: 6.7179
# Epoch 23 | Step 40 | Loss: 6.5167
# Epoch 23 | Step 50 | Loss: 6.8145
# Epoch 23 | Step 60 | Loss: 6.6040
# === Epoch 23 Finished | Avg Loss: 6.7710 ===
# Epoch 24 | Step 0 | Loss: 7.2072
# Epoch 24 | Step 10 | Loss: 6.7569
# Epoch 24 | Step 20 | Loss: 7.0698
# Epoch 24 | Step 30 | Loss: 6.6832
# Epoch 24 | Step 40 | Loss: 6.6904
# Epoch 24 | Step 50 | Loss: 6.8033
# Epoch 24 | Step 60 | Loss: 6.7915
# === Epoch 24 Finished | Avg Loss: 6.8546 ===
# Epoch 25 | Step 0 | Loss: 6.6879
# Epoch 25 | Step 10 | Loss: 7.1989
# Epoch 25 | Step 20 | Loss: 6.5015
# Epoch 25 | Step 30 | Loss: 6.7558
# Epoch 25 | Step 40 | Loss: 6.7652
# Epoch 25 | Step 50 | Loss: 6.6623
# Epoch 25 | Step 60 | Loss: 6.6403
# === Epoch 25 Finished | Avg Loss: 6.7423 ===
# Epoch 26 | Step 0 | Loss: 6.6726
# Epoch 26 | Step 10 | Loss: 6.5605
# Epoch 26 | Step 20 | Loss: 6.6968
# Epoch 26 | Step 30 | Loss: 6.6716
# Epoch 26 | Step 40 | Loss: 6.7692
# Epoch 26 | Step 50 | Loss: 6.7626
# Epoch 26 | Step 60 | Loss: 6.5716
# === Epoch 26 Finished | Avg Loss: 6.6685 ===
# Epoch 27 | Step 0 | Loss: 6.5540
# Epoch 27 | Step 10 | Loss: 6.9700
# Epoch 27 | Step 20 | Loss: 6.7525
# Epoch 27 | Step 30 | Loss: 6.8750
# Epoch 27 | Step 40 | Loss: 6.6310
# Epoch 27 | Step 50 | Loss: 6.7614
# Epoch 27 | Step 60 | Loss: 6.7422
# === Epoch 27 Finished | Avg Loss: 6.7195 ===
# Epoch 28 | Step 0 | Loss: 6.7515
# Epoch 28 | Step 10 | Loss: 7.0091
# Epoch 28 | Step 20 | Loss: 6.7617
# Epoch 28 | Step 30 | Loss: 6.6177
# Epoch 28 | Step 40 | Loss: 6.3798
# Epoch 28 | Step 50 | Loss: 6.7702
# Epoch 28 | Step 60 | Loss: 6.8842
# === Epoch 28 Finished | Avg Loss: 6.7514 ===
# Epoch 29 | Step 0 | Loss: 6.8098
# Epoch 29 | Step 10 | Loss: 6.7943
# Epoch 29 | Step 20 | Loss: 6.7514
# Epoch 29 | Step 30 | Loss: 6.6965
# Epoch 29 | Step 40 | Loss: 6.8675
# Epoch 29 | Step 50 | Loss: 6.9640
# Epoch 29 | Step 60 | Loss: 6.6787
# === Epoch 29 Finished | Avg Loss: 6.7174 ===
# Epoch 30 | Step 0 | Loss: 6.5442
# Epoch 30 | Step 10 | Loss: 6.8761
# Epoch 30 | Step 20 | Loss: 6.6949
# Epoch 30 | Step 30 | Loss: 6.5846
# Epoch 30 | Step 40 | Loss: 6.5814
# Epoch 30 | Step 50 | Loss: 6.6770
# Epoch 30 | Step 60 | Loss: 6.7912
# === Epoch 30 Finished | Avg Loss: 6.6862 ===
# Epoch 31 | Step 0 | Loss: 6.6794
# Epoch 31 | Step 10 | Loss: 6.6027
# Epoch 31 | Step 20 | Loss: 6.7351
# Epoch 31 | Step 30 | Loss: 6.7701
# Epoch 31 | Step 40 | Loss: 6.7137
# Epoch 31 | Step 50 | Loss: 6.6925
# Epoch 31 | Step 60 | Loss: 6.4804
# === Epoch 31 Finished | Avg Loss: 6.6628 ===
# Epoch 32 | Step 0 | Loss: 6.6842
# Epoch 32 | Step 10 | Loss: 6.6195
# Epoch 32 | Step 20 | Loss: 6.5839
# Epoch 32 | Step 30 | Loss: 6.7059
# Epoch 32 | Step 40 | Loss: 6.8123
# Epoch 32 | Step 50 | Loss: 6.7044
# Epoch 32 | Step 60 | Loss: 6.6128
# === Epoch 32 Finished | Avg Loss: 6.6689 ===
# Epoch 33 | Step 0 | Loss: 6.7681
# Epoch 33 | Step 10 | Loss: 6.5301
# Epoch 33 | Step 20 | Loss: 6.6761
# Epoch 33 | Step 30 | Loss: 6.5936
# Epoch 33 | Step 40 | Loss: 6.8246
# Epoch 33 | Step 50 | Loss: 6.6731
# Epoch 33 | Step 60 | Loss: 6.6843
# === Epoch 33 Finished | Avg Loss: 6.6549 ===
# Epoch 34 | Step 0 | Loss: 6.9221
# Epoch 34 | Step 10 | Loss: 6.6809
# Epoch 34 | Step 20 | Loss: 6.7248
# Epoch 34 | Step 30 | Loss: 6.5695
# Epoch 34 | Step 40 | Loss: 6.4916
# Epoch 34 | Step 50 | Loss: 6.7515
# Epoch 34 | Step 60 | Loss: 6.7675
# === Epoch 34 Finished | Avg Loss: 6.6661 ===
# Epoch 35 | Step 0 | Loss: 6.4889
# Epoch 35 | Step 10 | Loss: 6.6336
# Epoch 35 | Step 20 | Loss: 6.6028
# Epoch 35 | Step 30 | Loss: 6.5002
# Epoch 35 | Step 40 | Loss: 6.5354
# Epoch 35 | Step 50 | Loss: 6.5651
# Epoch 35 | Step 60 | Loss: 6.7606
# === Epoch 35 Finished | Avg Loss: 6.6185 ===
# Epoch 36 | Step 0 | Loss: 6.5300
# Epoch 36 | Step 10 | Loss: 6.5133
# Epoch 36 | Step 20 | Loss: 6.9276
# Epoch 36 | Step 30 | Loss: 6.4605
# Epoch 36 | Step 40 | Loss: 7.0911
# Epoch 36 | Step 50 | Loss: 6.4222
# Epoch 36 | Step 60 | Loss: 6.7134
# === Epoch 36 Finished | Avg Loss: 6.6845 ===
# Epoch 37 | Step 0 | Loss: 6.7043
# Epoch 37 | Step 10 | Loss: 6.5054
# Epoch 37 | Step 20 | Loss: 6.6329
# Epoch 37 | Step 30 | Loss: 6.6411
# Epoch 37 | Step 40 | Loss: 6.7628
# Epoch 37 | Step 50 | Loss: 6.4395
# Epoch 37 | Step 60 | Loss: 6.6202
# === Epoch 37 Finished | Avg Loss: 6.6568 ===
# Epoch 38 | Step 0 | Loss: 6.5962
# Epoch 38 | Step 10 | Loss: 6.5013
# Epoch 38 | Step 20 | Loss: 6.4959
# Epoch 38 | Step 30 | Loss: 6.6456
# Epoch 38 | Step 40 | Loss: 6.8411
# Epoch 38 | Step 50 | Loss: 6.4485
# Epoch 38 | Step 60 | Loss: 6.6908
# === Epoch 38 Finished | Avg Loss: 6.6218 ===
# Epoch 39 | Step 0 | Loss: 6.6053
# Epoch 39 | Step 10 | Loss: 6.6256
# Epoch 39 | Step 20 | Loss: 6.6056
# Epoch 39 | Step 30 | Loss: 6.8960
# Epoch 39 | Step 40 | Loss: 6.6212
# Epoch 39 | Step 50 | Loss: 6.5704
# Epoch 39 | Step 60 | Loss: 6.3934
# === Epoch 39 Finished | Avg Loss: 6.6527 ===
# Epoch 40 | Step 0 | Loss: 6.7641
# Epoch 40 | Step 10 | Loss: 6.6582
# Epoch 40 | Step 20 | Loss: 6.6974
# Epoch 40 | Step 30 | Loss: 7.0067
# Epoch 40 | Step 40 | Loss: 6.4404
# Epoch 40 | Step 50 | Loss: 6.4970
# Epoch 40 | Step 60 | Loss: 6.5180
# === Epoch 40 Finished | Avg Loss: 6.6935 ===
# Epoch 41 | Step 0 | Loss: 6.5006
# Epoch 41 | Step 10 | Loss: 6.5873
# Epoch 41 | Step 20 | Loss: 6.4961
# Epoch 41 | Step 30 | Loss: 6.6256
# Epoch 41 | Step 40 | Loss: 6.2864
# Epoch 41 | Step 50 | Loss: 6.8171
# Epoch 41 | Step 60 | Loss: 6.4627
# === Epoch 41 Finished | Avg Loss: 6.5940 ===
# Epoch 42 | Step 0 | Loss: 6.6421
# Epoch 42 | Step 10 | Loss: 6.6612
# Epoch 42 | Step 20 | Loss: 6.6347
# Epoch 42 | Step 30 | Loss: 6.5656
# Epoch 42 | Step 40 | Loss: 6.8090
# Epoch 42 | Step 50 | Loss: 6.5535
# Epoch 42 | Step 60 | Loss: 6.4844
# === Epoch 42 Finished | Avg Loss: 6.5974 ===
# Epoch 43 | Step 0 | Loss: 6.5978
# Epoch 43 | Step 10 | Loss: 6.5743
# Epoch 43 | Step 20 | Loss: 6.4855
# Epoch 43 | Step 30 | Loss: 6.5164
# Epoch 43 | Step 40 | Loss: 6.6130
# Epoch 43 | Step 50 | Loss: 6.6221
# Epoch 43 | Step 60 | Loss: 6.6119
# === Epoch 43 Finished | Avg Loss: 6.6134 ===
# Epoch 44 | Step 0 | Loss: 6.5751
# Epoch 44 | Step 10 | Loss: 6.8150
# Epoch 44 | Step 20 | Loss: 6.5472
# Epoch 44 | Step 30 | Loss: 6.5059
# Epoch 44 | Step 40 | Loss: 6.7468
# Epoch 44 | Step 50 | Loss: 6.5630
# Epoch 44 | Step 60 | Loss: 6.3709
# === Epoch 44 Finished | Avg Loss: 6.6027 ===
# Epoch 45 | Step 0 | Loss: 6.7911
# Epoch 45 | Step 10 | Loss: 6.3938
# Epoch 45 | Step 20 | Loss: 6.6227
# Epoch 45 | Step 30 | Loss: 6.7879
# Epoch 45 | Step 40 | Loss: 6.7764
# Epoch 45 | Step 50 | Loss: 6.5438
# Epoch 45 | Step 60 | Loss: 6.5947
# === Epoch 45 Finished | Avg Loss: 6.6648 ===
# Epoch 46 | Step 0 | Loss: 6.8564
# Epoch 46 | Step 10 | Loss: 6.6732
# Epoch 46 | Step 20 | Loss: 6.4262
# Epoch 46 | Step 30 | Loss: 6.7481
# Epoch 46 | Step 40 | Loss: 6.5896
# Epoch 46 | Step 50 | Loss: 6.5871
# Epoch 46 | Step 60 | Loss: 6.7385
# === Epoch 46 Finished | Avg Loss: 6.6375 ===
# Epoch 47 | Step 0 | Loss: 6.7443
# Epoch 47 | Step 10 | Loss: 6.6717
# Epoch 47 | Step 20 | Loss: 6.8250
# Epoch 47 | Step 30 | Loss: 6.5904
# Epoch 47 | Step 40 | Loss: 6.4374
# Epoch 47 | Step 50 | Loss: 6.7780
# Epoch 47 | Step 60 | Loss: 6.6833
# === Epoch 47 Finished | Avg Loss: 6.6281 ===
# Epoch 48 | Step 0 | Loss: 6.6033
# Epoch 48 | Step 10 | Loss: 6.4152
# Epoch 48 | Step 20 | Loss: 6.3703
# Epoch 48 | Step 30 | Loss: 6.5457
# Epoch 48 | Step 40 | Loss: 6.3703
# Epoch 48 | Step 50 | Loss: 6.3990
# Epoch 48 | Step 60 | Loss: 6.6686
# === Epoch 48 Finished | Avg Loss: 6.5221 ===
# Epoch 49 | Step 0 | Loss: 6.5785
# Epoch 49 | Step 10 | Loss: 6.6904
# Epoch 49 | Step 20 | Loss: 6.5137
# Epoch 49 | Step 30 | Loss: 6.4655
# Epoch 49 | Step 40 | Loss: 6.4840
# Epoch 49 | Step 50 | Loss: 6.3361
# Epoch 49 | Step 60 | Loss: 6.4342
# === Epoch 49 Finished | Avg Loss: 6.5351 ===
# Epoch 50 | Step 0 | Loss: 6.5615
# Epoch 50 | Step 10 | Loss: 6.4811
# Epoch 50 | Step 20 | Loss: 6.3860
# Epoch 50 | Step 30 | Loss: 6.4902
# Epoch 50 | Step 40 | Loss: 6.5289
# Epoch 50 | Step 50 | Loss: 6.4303
# Epoch 50 | Step 60 | Loss: 6.7657
# === Epoch 50 Finished | Avg Loss: 6.5105 ===
# Epoch 51 | Step 0 | Loss: 6.5404
# Epoch 51 | Step 10 | Loss: 6.3236
# Epoch 51 | Step 20 | Loss: 6.6079
# Epoch 51 | Step 30 | Loss: 6.6610
# Epoch 51 | Step 40 | Loss: 6.6182
# Epoch 51 | Step 50 | Loss: 6.7840
# Epoch 51 | Step 60 | Loss: 6.4050
# === Epoch 51 Finished | Avg Loss: 6.5300 ===
# Epoch 52 | Step 0 | Loss: 6.6485
# Epoch 52 | Step 10 | Loss: 6.4640
# Epoch 52 | Step 20 | Loss: 6.6357
# Epoch 52 | Step 30 | Loss: 6.5126
# Epoch 52 | Step 40 | Loss: 6.5988
# Epoch 52 | Step 50 | Loss: 6.6298
# Epoch 52 | Step 60 | Loss: 6.4412
# === Epoch 52 Finished | Avg Loss: 6.5529 ===
# Epoch 53 | Step 0 | Loss: 6.6198
# Epoch 53 | Step 10 | Loss: 6.5890
# Epoch 53 | Step 20 | Loss: 6.7296
# Epoch 53 | Step 30 | Loss: 6.3443
# Epoch 53 | Step 40 | Loss: 6.5044
# Epoch 53 | Step 50 | Loss: 6.4238
# Epoch 53 | Step 60 | Loss: 6.6179
# === Epoch 53 Finished | Avg Loss: 6.5668 ===
# Epoch 54 | Step 0 | Loss: 6.5624
# Epoch 54 | Step 10 | Loss: 6.5845
# Epoch 54 | Step 20 | Loss: 6.6322
# Epoch 54 | Step 30 | Loss: 6.5956
# Epoch 54 | Step 40 | Loss: 6.5089
# Epoch 54 | Step 50 | Loss: 6.4573
# Epoch 54 | Step 60 | Loss: 6.3950
# === Epoch 54 Finished | Avg Loss: 6.5593 ===
# Epoch 55 | Step 0 | Loss: 6.7042
# Epoch 55 | Step 10 | Loss: 6.7016
# Epoch 55 | Step 20 | Loss: 6.2612
# Epoch 55 | Step 30 | Loss: 6.4492
# Epoch 55 | Step 40 | Loss: 6.4020
# Epoch 55 | Step 50 | Loss: 6.4124
# Epoch 55 | Step 60 | Loss: 6.4540
# === Epoch 55 Finished | Avg Loss: 6.5123 ===
# Epoch 56 | Step 0 | Loss: 6.6382
# Epoch 56 | Step 10 | Loss: 6.4705
# Epoch 56 | Step 20 | Loss: 6.6217
# Epoch 56 | Step 30 | Loss: 6.4646
# Epoch 56 | Step 40 | Loss: 6.4581
# Epoch 56 | Step 50 | Loss: 6.4196
# Epoch 56 | Step 60 | Loss: 6.6128
# === Epoch 56 Finished | Avg Loss: 6.5504 ===
# Epoch 57 | Step 0 | Loss: 6.3329
# Epoch 57 | Step 10 | Loss: 6.2209
# Epoch 57 | Step 20 | Loss: 6.4600
# Epoch 57 | Step 30 | Loss: 6.5098
# Epoch 57 | Step 40 | Loss: 6.5235
# Epoch 57 | Step 50 | Loss: 6.6049
# Epoch 57 | Step 60 | Loss: 6.5923
# === Epoch 57 Finished | Avg Loss: 6.4896 ===
# Epoch 58 | Step 0 | Loss: 6.3353
# Epoch 58 | Step 10 | Loss: 6.6085
# Epoch 58 | Step 20 | Loss: 6.3633
# Epoch 58 | Step 30 | Loss: 6.4699
# Epoch 58 | Step 40 | Loss: 6.5392
# Epoch 58 | Step 50 | Loss: 6.5334
# Epoch 58 | Step 60 | Loss: 6.3508
# === Epoch 58 Finished | Avg Loss: 6.4746 ===
# Epoch 59 | Step 0 | Loss: 6.5888
# Epoch 59 | Step 10 | Loss: 6.3826
# Epoch 59 | Step 20 | Loss: 6.5956
# Epoch 59 | Step 30 | Loss: 6.6974
# Epoch 59 | Step 40 | Loss: 6.6839
# Epoch 59 | Step 50 | Loss: 6.3814
# Epoch 59 | Step 60 | Loss: 6.6049
# === Epoch 59 Finished | Avg Loss: 6.5304 ===
# Epoch 60 | Step 0 | Loss: 6.5008
# Epoch 60 | Step 10 | Loss: 6.2850
# Epoch 60 | Step 20 | Loss: 6.6206
# Epoch 60 | Step 30 | Loss: 6.3836
# Epoch 60 | Step 40 | Loss: 6.4380
# Epoch 60 | Step 50 | Loss: 6.5176
# Epoch 60 | Step 60 | Loss: 6.6136
# === Epoch 60 Finished | Avg Loss: 6.4845 ===
# Epoch 61 | Step 0 | Loss: 6.6095
# Epoch 61 | Step 10 | Loss: 6.5513
# Epoch 61 | Step 20 | Loss: 6.3240
# Epoch 61 | Step 30 | Loss: 6.4187
# Epoch 61 | Step 40 | Loss: 6.6059
# Epoch 61 | Step 50 | Loss: 6.4557
# Epoch 61 | Step 60 | Loss: 6.4146
# === Epoch 61 Finished | Avg Loss: 6.5065 ===
# Epoch 62 | Step 0 | Loss: 6.6063
# Epoch 62 | Step 10 | Loss: 6.5674
# Epoch 62 | Step 20 | Loss: 6.3757
# Epoch 62 | Step 30 | Loss: 6.4779
# Epoch 62 | Step 40 | Loss: 6.4566
# Epoch 62 | Step 50 | Loss: 6.4650
# Epoch 62 | Step 60 | Loss: 6.4651
# === Epoch 62 Finished | Avg Loss: 6.5144 ===
# Epoch 63 | Step 0 | Loss: 6.3286
# Epoch 63 | Step 10 | Loss: 6.4427
# Epoch 63 | Step 20 | Loss: 6.7080
# Epoch 63 | Step 30 | Loss: 6.4395
# Epoch 63 | Step 40 | Loss: 6.5760
# Epoch 63 | Step 50 | Loss: 6.4261
# Epoch 63 | Step 60 | Loss: 6.4809
# === Epoch 63 Finished | Avg Loss: 6.4883 ===
# Epoch 64 | Step 0 | Loss: 6.3750
# Epoch 64 | Step 10 | Loss: 6.3963
# Epoch 64 | Step 20 | Loss: 6.4800
# Epoch 64 | Step 30 | Loss: 6.5852
# Epoch 64 | Step 40 | Loss: 6.5258
# Epoch 64 | Step 50 | Loss: 6.3802
# Epoch 64 | Step 60 | Loss: 6.6463
# === Epoch 64 Finished | Avg Loss: 6.5279 ===
# Epoch 65 | Step 0 | Loss: 6.5271
# Epoch 65 | Step 10 | Loss: 6.5386
# Epoch 65 | Step 20 | Loss: 6.6230
# Epoch 65 | Step 30 | Loss: 6.6508
# Epoch 65 | Step 40 | Loss: 6.5736
# Epoch 65 | Step 50 | Loss: 6.4660
# Epoch 65 | Step 60 | Loss: 6.5674
# === Epoch 65 Finished | Avg Loss: 6.5091 ===
# Epoch 66 | Step 0 | Loss: 6.5300
# Epoch 66 | Step 10 | Loss: 6.5406
# Epoch 66 | Step 20 | Loss: 6.5246
# Epoch 66 | Step 30 | Loss: 6.6960
# Epoch 66 | Step 40 | Loss: 6.5754
# Epoch 66 | Step 50 | Loss: 6.4481
# Epoch 66 | Step 60 | Loss: 6.3915
# === Epoch 66 Finished | Avg Loss: 6.4823 ===
# Epoch 67 | Step 0 | Loss: 6.6482
# Epoch 67 | Step 10 | Loss: 6.8416
# Epoch 67 | Step 20 | Loss: 6.4514
# Epoch 67 | Step 30 | Loss: 6.5987
# Epoch 67 | Step 40 | Loss: 6.4714
# Epoch 67 | Step 50 | Loss: 6.5472
# Epoch 67 | Step 60 | Loss: 6.3931
# === Epoch 67 Finished | Avg Loss: 6.5122 ===
# Epoch 68 | Step 0 | Loss: 6.3183
# Epoch 68 | Step 10 | Loss: 6.4624
# Epoch 68 | Step 20 | Loss: 6.5437
# Epoch 68 | Step 30 | Loss: 6.5272
# Epoch 68 | Step 40 | Loss: 6.4333
# Epoch 68 | Step 50 | Loss: 6.5879
# Epoch 68 | Step 60 | Loss: 6.5314
# === Epoch 68 Finished | Avg Loss: 6.4987 ===
# Epoch 69 | Step 0 | Loss: 6.4385
# Epoch 69 | Step 10 | Loss: 6.4148
# Epoch 69 | Step 20 | Loss: 6.3049
# Epoch 69 | Step 30 | Loss: 6.4684
# Epoch 69 | Step 40 | Loss: 6.4035
# Epoch 69 | Step 50 | Loss: 6.7215
# Epoch 69 | Step 60 | Loss: 6.4850
# === Epoch 69 Finished | Avg Loss: 6.4652 ===
# Epoch 70 | Step 0 | Loss: 6.5742
# Epoch 70 | Step 10 | Loss: 6.3548
# Epoch 70 | Step 20 | Loss: 6.3621
# Epoch 70 | Step 30 | Loss: 6.3544
# Epoch 70 | Step 40 | Loss: 6.5613
# Epoch 70 | Step 50 | Loss: 6.4505
# Epoch 70 | Step 60 | Loss: 6.4238
# === Epoch 70 Finished | Avg Loss: 6.4820 ===
# Epoch 71 | Step 0 | Loss: 6.4997
# Epoch 71 | Step 10 | Loss: 6.5292
# Epoch 71 | Step 20 | Loss: 6.4061
# Epoch 71 | Step 30 | Loss: 6.4467
# Epoch 71 | Step 40 | Loss: 6.5451
# Epoch 71 | Step 50 | Loss: 6.6255
# Epoch 71 | Step 60 | Loss: 6.4659
# === Epoch 71 Finished | Avg Loss: 6.4879 ===
# Epoch 72 | Step 0 | Loss: 6.4809
# Epoch 72 | Step 10 | Loss: 6.5099
# Epoch 72 | Step 20 | Loss: 6.5930
# Epoch 72 | Step 30 | Loss: 6.8002
# Epoch 72 | Step 40 | Loss: 6.3721
# Epoch 72 | Step 50 | Loss: 6.5007
# Epoch 72 | Step 60 | Loss: 6.3946
# === Epoch 72 Finished | Avg Loss: 6.4842 ===
# Epoch 73 | Step 0 | Loss: 6.3699
# Epoch 73 | Step 10 | Loss: 6.4203
# Epoch 73 | Step 20 | Loss: 6.7409
# Epoch 73 | Step 30 | Loss: 6.5049
# Epoch 73 | Step 40 | Loss: 6.5793
# Epoch 73 | Step 50 | Loss: 6.6358
# Epoch 73 | Step 60 | Loss: 6.5167
# === Epoch 73 Finished | Avg Loss: 6.5067 ===
# Epoch 74 | Step 0 | Loss: 6.5411
# Epoch 74 | Step 10 | Loss: 6.4334
# Epoch 74 | Step 20 | Loss: 6.5731
# Epoch 74 | Step 30 | Loss: 6.4598
# Epoch 74 | Step 40 | Loss: 6.3401
# Epoch 74 | Step 50 | Loss: 6.2780
# Epoch 74 | Step 60 | Loss: 6.4588
# === Epoch 74 Finished | Avg Loss: 6.4899 ===
# Epoch 75 | Step 0 | Loss: 6.3641
# Epoch 75 | Step 10 | Loss: 6.7179
# Epoch 75 | Step 20 | Loss: 6.3643
# Epoch 75 | Step 30 | Loss: 6.4133
# Epoch 75 | Step 40 | Loss: 6.6272
# Epoch 75 | Step 50 | Loss: 6.2647
# Epoch 75 | Step 60 | Loss: 6.5535
# === Epoch 75 Finished | Avg Loss: 6.4785 ===
# Epoch 76 | Step 0 | Loss: 6.7811
# Epoch 76 | Step 10 | Loss: 6.6032
# Epoch 76 | Step 20 | Loss: 6.3397
# Epoch 76 | Step 30 | Loss: 6.3510
# Epoch 76 | Step 40 | Loss: 6.3418
# Epoch 76 | Step 50 | Loss: 6.5030
# Epoch 76 | Step 60 | Loss: 6.4877
# === Epoch 76 Finished | Avg Loss: 6.4698 ===
# Epoch 77 | Step 0 | Loss: 6.4577
# Epoch 77 | Step 10 | Loss: 6.4363
# Epoch 77 | Step 20 | Loss: 6.4025
# Epoch 77 | Step 30 | Loss: 6.5074
# Epoch 77 | Step 40 | Loss: 6.3854
# Epoch 77 | Step 50 | Loss: 6.6319
# Epoch 77 | Step 60 | Loss: 6.5825
# === Epoch 77 Finished | Avg Loss: 6.4757 ===
# Epoch 78 | Step 0 | Loss: 6.4231
# Epoch 78 | Step 10 | Loss: 6.5455
# Epoch 78 | Step 20 | Loss: 6.4870
# Epoch 78 | Step 30 | Loss: 6.4249
# Epoch 78 | Step 40 | Loss: 6.4080
# Epoch 78 | Step 50 | Loss: 6.4518
# Epoch 78 | Step 60 | Loss: 6.2558
# === Epoch 78 Finished | Avg Loss: 6.4841 ===
# Epoch 79 | Step 0 | Loss: 6.3445
# Epoch 79 | Step 10 | Loss: 6.6109
# Epoch 79 | Step 20 | Loss: 6.1542
# Epoch 79 | Step 30 | Loss: 6.5353
# Epoch 79 | Step 40 | Loss: 6.5926
# Epoch 79 | Step 50 | Loss: 6.4174
# Epoch 79 | Step 60 | Loss: 6.4010
# === Epoch 79 Finished | Avg Loss: 6.4713 ===
# Epoch 80 | Step 0 | Loss: 6.6824
# Epoch 80 | Step 10 | Loss: 6.5773
# Epoch 80 | Step 20 | Loss: 6.4903
# Epoch 80 | Step 30 | Loss: 6.4627
# Epoch 80 | Step 40 | Loss: 6.4717
# Epoch 80 | Step 50 | Loss: 6.5539
# Epoch 80 | Step 60 | Loss: 6.3689
# === Epoch 80 Finished | Avg Loss: 6.4923 ===
# Epoch 81 | Step 0 | Loss: 6.5998
# Epoch 81 | Step 10 | Loss: 6.6709
# Epoch 81 | Step 20 | Loss: 6.2818
# Epoch 81 | Step 30 | Loss: 6.4987
# Epoch 81 | Step 40 | Loss: 6.5615
# Epoch 81 | Step 50 | Loss: 6.5423
# Epoch 81 | Step 60 | Loss: 6.5724
# === Epoch 81 Finished | Avg Loss: 6.4757 ===
# Epoch 82 | Step 0 | Loss: 6.4680
# Epoch 82 | Step 10 | Loss: 6.5822
# Epoch 82 | Step 20 | Loss: 6.5250
# Epoch 82 | Step 30 | Loss: 6.4719
# Epoch 82 | Step 40 | Loss: 6.3985
# Epoch 82 | Step 50 | Loss: 6.6566
# Epoch 82 | Step 60 | Loss: 6.3582
# === Epoch 82 Finished | Avg Loss: 6.4892 ===
# Epoch 83 | Step 0 | Loss: 6.5122
# Epoch 83 | Step 10 | Loss: 6.5067
# Epoch 83 | Step 20 | Loss: 6.6416
# Epoch 83 | Step 30 | Loss: 6.6134
# Epoch 83 | Step 40 | Loss: 6.4339
# Epoch 83 | Step 50 | Loss: 6.5067
# Epoch 83 | Step 60 | Loss: 6.6302
# === Epoch 83 Finished | Avg Loss: 6.4761 ===
# Epoch 84 | Step 0 | Loss: 6.5540
# Epoch 84 | Step 10 | Loss: 6.4109
# Epoch 84 | Step 20 | Loss: 6.6444
# Epoch 84 | Step 30 | Loss: 6.7489
# Epoch 84 | Step 40 | Loss: 6.2929
# Epoch 84 | Step 50 | Loss: 6.2232
# Epoch 84 | Step 60 | Loss: 6.5651
# === Epoch 84 Finished | Avg Loss: 6.4884 ===
# Epoch 85 | Step 0 | Loss: 6.3632
# Epoch 85 | Step 10 | Loss: 6.5556
# Epoch 85 | Step 20 | Loss: 6.6555
# Epoch 85 | Step 30 | Loss: 6.3276
# Epoch 85 | Step 40 | Loss: 6.3571
# Epoch 85 | Step 50 | Loss: 6.3820
# Epoch 85 | Step 60 | Loss: 6.5269
# === Epoch 85 Finished | Avg Loss: 6.4697 ===
# Epoch 86 | Step 0 | Loss: 6.4926
# Epoch 86 | Step 10 | Loss: 6.4088
# Epoch 86 | Step 20 | Loss: 6.3094
# Epoch 86 | Step 30 | Loss: 6.6780
# Epoch 86 | Step 40 | Loss: 6.3458
# Epoch 86 | Step 50 | Loss: 6.6987
# Epoch 86 | Step 60 | Loss: 6.5435
# === Epoch 86 Finished | Avg Loss: 6.4796 ===
# Epoch 87 | Step 0 | Loss: 6.4771
# Epoch 87 | Step 10 | Loss: 6.6269
# Epoch 87 | Step 20 | Loss: 6.5011
# Epoch 87 | Step 30 | Loss: 6.4345
# Epoch 87 | Step 40 | Loss: 6.3321
# Epoch 87 | Step 50 | Loss: 6.6817
# Epoch 87 | Step 60 | Loss: 6.5863
# === Epoch 87 Finished | Avg Loss: 6.4759 ===
# Epoch 88 | Step 0 | Loss: 6.4017
# Epoch 88 | Step 10 | Loss: 6.7047
# Epoch 88 | Step 20 | Loss: 6.6000
# Epoch 88 | Step 30 | Loss: 6.6040
# Epoch 88 | Step 40 | Loss: 6.4944
# Epoch 88 | Step 50 | Loss: 6.5190
# Epoch 88 | Step 60 | Loss: 6.5384
# === Epoch 88 Finished | Avg Loss: 6.4902 ===
# Epoch 89 | Step 0 | Loss: 6.3021
# Epoch 89 | Step 10 | Loss: 6.4680
# Epoch 89 | Step 20 | Loss: 6.2997
# Epoch 89 | Step 30 | Loss: 6.4421
# Epoch 89 | Step 40 | Loss: 6.3346
# Epoch 89 | Step 50 | Loss: 6.5214
# Epoch 89 | Step 60 | Loss: 6.6334
# === Epoch 89 Finished | Avg Loss: 6.4658 ===
# Epoch 90 | Step 0 | Loss: 6.4342
# Epoch 90 | Step 10 | Loss: 6.6167
# Epoch 90 | Step 20 | Loss: 6.4968
# Epoch 90 | Step 30 | Loss: 6.4446
# Epoch 90 | Step 40 | Loss: 6.6172
# Epoch 90 | Step 50 | Loss: 6.3698
# Epoch 90 | Step 60 | Loss: 6.5554
# === Epoch 90 Finished | Avg Loss: 6.4657 ===
# Epoch 91 | Step 0 | Loss: 6.5542
# Epoch 91 | Step 10 | Loss: 6.6668
# Epoch 91 | Step 20 | Loss: 6.3865
# Epoch 91 | Step 30 | Loss: 6.4379
# Epoch 91 | Step 40 | Loss: 6.3569
# Epoch 91 | Step 50 | Loss: 6.5664
# Epoch 91 | Step 60 | Loss: 6.3903
# === Epoch 91 Finished | Avg Loss: 6.4650 ===
# Epoch 92 | Step 0 | Loss: 6.3429
# Epoch 92 | Step 10 | Loss: 6.6136
# Epoch 92 | Step 20 | Loss: 6.3700
# Epoch 92 | Step 30 | Loss: 6.6877
# Epoch 92 | Step 40 | Loss: 6.4185
# Epoch 92 | Step 50 | Loss: 6.4442
# Epoch 92 | Step 60 | Loss: 6.6043
# === Epoch 92 Finished | Avg Loss: 6.4633 ===
# Epoch 93 | Step 0 | Loss: 6.5220
# Epoch 93 | Step 10 | Loss: 6.4607
# Epoch 93 | Step 20 | Loss: 6.5248
# Epoch 93 | Step 30 | Loss: 6.3722
# Epoch 93 | Step 40 | Loss: 6.5207
# Epoch 93 | Step 50 | Loss: 6.3030
# Epoch 93 | Step 60 | Loss: 6.6258
# === Epoch 93 Finished | Avg Loss: 6.4654 ===
# Epoch 94 | Step 0 | Loss: 6.3672
# Epoch 94 | Step 10 | Loss: 6.6249
# Epoch 94 | Step 20 | Loss: 6.4955
# Epoch 94 | Step 30 | Loss: 6.4854
# Epoch 94 | Step 40 | Loss: 6.5251
# Epoch 94 | Step 50 | Loss: 6.5716
# Epoch 94 | Step 60 | Loss: 6.4077
# === Epoch 94 Finished | Avg Loss: 6.4495 ===
# Epoch 95 | Step 0 | Loss: 6.4740
# Epoch 95 | Step 10 | Loss: 6.3944
# Epoch 95 | Step 20 | Loss: 6.4169
# Epoch 95 | Step 30 | Loss: 6.3546
# Epoch 95 | Step 40 | Loss: 6.3658
# Epoch 95 | Step 50 | Loss: 6.4678
# Epoch 95 | Step 60 | Loss: 6.3281
# === Epoch 95 Finished | Avg Loss: 6.4635 ===
# Epoch 96 | Step 0 | Loss: 6.5300
# Epoch 96 | Step 10 | Loss: 6.4067
# Epoch 96 | Step 20 | Loss: 6.5391
# Epoch 96 | Step 30 | Loss: 6.4645
# Epoch 96 | Step 40 | Loss: 6.5581
# Epoch 96 | Step 50 | Loss: 6.7087
# Epoch 96 | Step 60 | Loss: 6.5441
# === Epoch 96 Finished | Avg Loss: 6.4615 ===
# Epoch 97 | Step 0 | Loss: 6.4905
# Epoch 97 | Step 10 | Loss: 6.5833
# Epoch 97 | Step 20 | Loss: 6.3924
# Epoch 97 | Step 30 | Loss: 6.7244
# Epoch 97 | Step 40 | Loss: 6.5566
# Epoch 97 | Step 50 | Loss: 6.4259
# Epoch 97 | Step 60 | Loss: 6.5524
# === Epoch 97 Finished | Avg Loss: 6.4698 ===
# Epoch 98 | Step 0 | Loss: 6.5274
# Epoch 98 | Step 10 | Loss: 6.6452
# Epoch 98 | Step 20 | Loss: 6.4558
# Epoch 98 | Step 30 | Loss: 6.3242
# Epoch 98 | Step 40 | Loss: 6.4618
# Epoch 98 | Step 50 | Loss: 6.3443
# Epoch 98 | Step 60 | Loss: 6.5964
# === Epoch 98 Finished | Avg Loss: 6.4645 ===
# Epoch 99 | Step 0 | Loss: 6.3016
# Epoch 99 | Step 10 | Loss: 6.3921
# Epoch 99 | Step 20 | Loss: 6.4752
# Epoch 99 | Step 30 | Loss: 6.4065
# Epoch 99 | Step 40 | Loss: 6.3650
# Epoch 99 | Step 50 | Loss: 6.5000
# Epoch 99 | Step 60 | Loss: 6.4818
# === Epoch 99 Finished | Avg Loss: 6.4904 ===
# Epoch 100 | Step 0 | Loss: 6.5236
# Epoch 100 | Step 10 | Loss: 6.2500
# Epoch 100 | Step 20 | Loss: 6.5115
# Epoch 100 | Step 30 | Loss: 6.3575
# Epoch 100 | Step 40 | Loss: 6.6346
# Epoch 100 | Step 50 | Loss: 6.4346
# Epoch 100 | Step 60 | Loss: 6.6203
# === Epoch 100 Finished | Avg Loss: 6.4604 ===
# All training finished. Model saved.

# %% [markdown]
# ## 5. 音の確認用コード

# %%
def listen_current_model(model):
    print("▼▼▼ Epoch 10 時点の音色チェック ▼▼▼")

    # 3種類の音色をテスト (0:Flute/Sine, 1:Violin/Saw, 2:Clarinet/Square)
    test_ids = [0, 1, 2]
    inst_names = ["Flute (Sine)", "Violin (Saw)", "Clarinet (Square)"]

    # テスト用入力データの作成 (ド・ミ・ソ...と動く)
    duration = 4.0
    n_frames = int(duration * SAMPLE_RATE / HOP_LENGTH)
    t = np.linspace(0, duration, n_frames, endpoint=False)

    # 音程: 220Hzから始まり、1秒ごとに倍音列を登る
    f0 = 220.0 * (1 + np.floor(t)) # 220, 440, 660, 880
    f0 = f0.astype(np.float32)
    f0_tensor = torch.from_numpy(f0).view(1, -1, 1).to(device)

    # その他ダミー
    f0_norm = torch.zeros_like(f0_tensor).to(device)
    loud_norm = torch.ones_like(f0_tensor).to(device) * 0.8 # 音量は大きめに

    model.eval()
    import IPython.display as ipd

    with torch.no_grad():
        for i, name in zip(test_ids, inst_names):
            inst_id = torch.tensor([i], device=device).long()

            # 生成
            audio = model(f0_tensor, f0_norm, loud_norm, inst_id)
            audio_np = audio.cpu().numpy().flatten()

            print(f"--- {name} ---")
            ipd.display(ipd.Audio(audio_np, rate=SAMPLE_RATE))

# 実行
listen_current_model(model)
# Out:
# ▼▼▼ Epoch 10 時点の音色チェック ▼▼▼
# --- Flute (Sine) ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# --- Violin (Saw) ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# --- Clarinet (Square) ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def test_forced_generation_fixed():
    print("強制生成テスト（修正版）開始...")

    # 設定
    duration = 4.0
    # ★修正点1: 時間軸は「サンプル数」ではなく「フレーム数」で作る
    n_frames = int(duration * SAMPLE_RATE / HOP_LENGTH)

    # 0.0秒 〜 4.0秒 までを n_frames 分割
    t_frames = np.linspace(0, duration, n_frames, endpoint=False)

    # ★修正点2: f0もフレーム単位で作る
    # 1秒ごとに100Hz上がる (220, 320, 420...)
    f0_dummy = 220.0 + (np.floor(t_frames) * 100.0)
    f0_dummy = f0_dummy.astype(np.float32)

    # Tensor化 [1, T_frames, 1]
    f0_tensor = torch.from_numpy(f0_dummy).view(1, -1, 1).to(device)

    # 他のダミー入力もフレーム長に合わせる
    f0_norm = torch.zeros_like(f0_tensor).to(device)
    loud_norm = torch.ones_like(f0_tensor).to(device)
    inst_id = torch.tensor([0], device=device).long()

    # モデル設定（強制モードのまま）
    model.eval()
    with torch.no_grad():
        # これで出力は [1, n_frames * 64] になるはず
        audio_out = model(f0_tensor, f0_norm, loud_norm, inst_id)

    audio_np = audio_out.cpu().numpy().flatten()

    print(f"生成された音声の長さ: {len(audio_np)} サンプル ({len(audio_np)/SAMPLE_RATE:.2f}秒)")
    print("▼▼▼ 再生 ▼▼▼")

    import IPython.display as ipd
    ipd.display(ipd.Audio(audio_np, rate=SAMPLE_RATE))

# 実行
test_forced_generation_fixed()
# Out:
# 強制生成テスト（修正版）開始...
# 生成された音声の長さ: 64000 サンプル (4.00秒)
# ▼▼▼ 再生 ▼▼▼
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 音の確認用コードの詳細
#
# このコードは、学習が完了したDDSPモデルを使用して音声を生成し、その生成された音声と元の音声とを比較・確認するためのものです。
#
# #### 1. 保存された重みファイルの検索とロード
#
# -   **`list_of_files = glob.glob('ddsp_trumpet_*.pth')`**:
#     -   `glob`モジュールを使用して、現在のディレクトリにある`ddsp_trumpet_`で始まるすべての`.pth`ファイル（モデルの学習済み重みが保存されているファイル）を検索します。
# -   **エラーチェックと最新ファイルの選択**:
#     -   `len(list_of_files) == 0`でファイルが見つからない場合はエラーメッセージを表示します。
#     -   `latest_file = max(list_of_files, key=os.path.getctime)`: 複数の`.pth`ファイルが見つかった場合、`os.path.getctime`（最終更新時刻）をキーとして、最も新しい（最後に学習された）モデルの重みファイルを選択します。
# -   **モデルの再構築と重みのロード**:
#     -   `device = 'cuda' if torch.cuda.is_available() else 'cpu'`: GPUが利用可能であればGPUを、そうでなければCPUを使用するように設定します。
#     -   `model = DDSP().to(device)`: 新しい`DDSP`モデルのインスタンスを生成し、適切なデバイスに移動します。
#     -   `model.load_state_dict(torch.load(latest_file, map_location=device))`: 選択した`.pth`ファイルから学習済み重みをロードします。`map_location=device`は、保存時と異なるデバイスでロードする場合に、重みを現在のデバイスにマッピングするために必要です。
#     -   `model.eval()`: モデルを評価モードに設定します。これにより、Batch NormalizationやDropoutなどの学習時のみ有効な層が無効になり、一貫した出力を得られます。
#
# #### 2. 音声の生成と確認
#
# -   **`with torch.no_grad():`**:
#     -   推論時には勾配計算が不要なため、`torch.no_grad()`ブロックを使用します。これによりメモリ使用量が削減され、計算が高速化されます。
# -   **データセットからのサンプル取得**:
#     -   `if 'dataset' not in globals():`: もし`dataset`変数がまだ定義されていなければ、`SingleViolinDataset`を再生成します。
#     -   `sample = dataset[0]`: データセットから最初のサンプルを取得します。このサンプルには、F0、ラウドネス、および元のオーディオ波形が含まれています。
# -   **モデル入力の準備**:
#     -   `f0_hz = sample['f0'].unsqueeze(0).to(device)`:
#         -   `sample['f0']`はデータセットで抽出されたHz単位のF0です。
#         -   `unsqueeze(0)`は、モデルが期待するバッチ次元（`[Batch, Time, Features]`）を追加します。
#         -   `.to(device)`でデバイスに転送します。
#     -   `f0_norm = sample['f0_norm'].unsqueeze(0).to(device)`:
#         -   `sample['f0_norm']`はデータセットで正規化されたF0です。
#         -   同様にバッチ次元を追加し、デバイスに転送します。
#     -   `loudness_norm = sample['loudness_norm'].unsqueeze(0).to(device)`:
#         -   `sample['loudness_norm']`はデータセットで正規化されたラウドネスです。
#         -   同様にバッチ次元を追加し、デバイスに転送します。
# -   **モデルによる音声生成**:
#     -   `audio_out = model(f0_hz, f0_norm, loudness_norm)`: 準備された入力（物理量F0、正規化F0、正規化ラウドネス）をモデルに渡し、合成されたオーディオ (`audio_out`) を取得します。
# -   **生成音声と元の音声の再生**:
#     -   `ipd.display(ipd.Audio(audio_out.cpu().numpy().squeeze(), rate=16000))`: 生成されたオーディオをCPUに移動し、Numpy配列に変換し、不要な次元を削除（`squeeze()`）した後、`IPython.display.Audio`でColab上に再生します。
#     -   `ipd.display(ipd.Audio(sample['audio'].numpy(), rate=16000))`: 元のオーディオも同様に再生し、生成された音声との比較を容易にします。
#
# このコードを実行することで、学習されたDDSPモデルがどれだけ元の音声をうまく再現できているか、耳で確認することができます。

# %%
# 推論時のデバッグ用コード例
# モデルのforwardを少し改造して、harmとnoiseを別々に返すモードを作るか、
# あるいは以下のように手動で内部の関数を呼ぶと確実です。

# (推論セルの中で)
with torch.no_grad():
    # 1. MLPを通す
    x = torch.cat([f0_norm, loudness_norm], dim=-1)
    x = model.mlp(x)
    x, _ = model.gru(x)

    # 2. パラメータ計算
    amp = torch.exp(model.dense_amp(x))
    harm_dist = F.softmax(model.dense_harm(x), dim=-1)
    noise_coeffs = torch.exp(model.dense_noise(x))

    # 3. 別々に合成
    audio_harm = model.harmonic_synth(f0, harm_dist, amp).squeeze()
    audio_noise = model.noise_synth(noise_coeffs).squeeze()

    # 合成
    audio_full = audio_harm + audio_noise

# 4. 保存して聴き比べ
ipd.display(ipd.Audio(audio_harm.cpu().numpy().squeeze(), rate=16000))
ipd.display(ipd.Audio(audio_noise.cpu().numpy().squeeze(), rate=16000))
ipd.display(ipd.Audio(audio_full.cpu().numpy().squeeze(), rate=16000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-766805868.py in <cell line: 0>()
#       6 with torch.no_grad():
#       7     # 1. MLPを通す
# ----> 8     x = torch.cat([f0_norm, loudness_norm], dim=-1)
#       9     x = model.mlp(x)
#      10     x, _ = model.gru(x)
#
# NameError: name 'f0_norm' is not defined
