# %%
# ========================================
# 💾 日常コミット用（これだけ実行すればOK）
# ========================================

# === 設定（ここだけ変更） ===
MESSAGE = "DDSP_two_stream"  # ← ここだけ変更してください

# === 実行（変更不要） ===
import os
from google.colab import drive
from google.colab import userdata


MESSAGE = "harmony_VAE_DDSP"
USER = "hiroki0427"
TOKEN = userdata.get('GITHUB_TOKEN')


# Google Drive マウント
drive.mount('/content/drive')

# プロジェクトフォルダに移動
os.chdir('/content/drive/MyDrive/hioki_lab')  # ← プロジェクト名に合わせて変更

# これにより、Gitコマンドがパスワードを聞かずにこのトークンを使います
with open(os.path.expanduser("~/.netrc"), "w") as f:
    f.write(f"machine github.com login {USER} password {TOKEN}\n")
# !chmod 600 ~/.netrc  # セキュリティ設定

# Git設定（毎回実行で安全）
# !git config --global user.name "hiroki0427"
# !git config --global user.email "hiroki0427jp@icloud.com"

# 5. リモートURLを標準的なものに戻す（トークンを埋め込まない形式でOKになります）
# !git remote set-url origin https://github.com/{USER}/DDSP_Application_Research.git

# コミット実行
print(f"💾 コミット中: {MESSAGE}")
# !git add .
# !git commit -m "{MESSAGE}"
# !git push origin main
print("✅ 完了!")
# Out:
# Mounted at /content/drive
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 💾 コミット中: harmony_VAE_DDSP
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# ✅ 完了!

# %%
import os
from google.colab import userdata

USER = "hiroki0427"
TOKEN = userdata.get('GITHUB_TOKEN')

# 1. リポジトリのルートへ移動
os.chdir('/content/drive/MyDrive/hioki_lab')

# 2. 認証設定 (fetchなど通信を行うために必要)
with open(os.path.expanduser("~/.netrc"), "w") as f:
    f.write(f"machine github.com login {USER} password {TOKEN}\n")
# !chmod 600 ~/.netrc

# 3. Gitリポジトリの再構築と紐づけ
print("🔄 Gitリポジトリを初期化・再構築しています...")
# !git init
# !git remote add origin https://github.com/{USER}/DDSP_Application_Research.git

# 4. GitHub上の履歴を取得し、ローカルのファイルはそのままにして履歴だけを同期
# !git fetch origin
# !git branch -M main
# !git reset origin/main

print("✅ リポジトリの修復と紐づけが完了しました！")
# Out:
# 🔄 Gitリポジトリを初期化・再構築しています...
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/hioki_lab/.git/
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 39 (delta 19), reused 29 (delta 9), pack-reused 0 (from 0)
# Unpacking objects: 100% (39/39), 2.96 MiB | 2.09 MiB/s, done.
# From https://github.com/hiroki0427/DDSP_Application_Research
#  * [new branch]      main       -> origin/main
# ...
