# %%
# ========================================
# 💾 日常コミット用（これだけ実行すればOK）
# ========================================

# === 設定（ここだけ変更） ===
MESSAGE = "initial commit"  # ← ここだけ変更してください

# === 実行（変更不要） ===
import os
from google.colab import drive

# Google Drive マウント
drive.mount('/content/drive')

# プロジェクトフォルダに移動
os.chdir('/content/drive/MyDrive/hioki_lab')  # ← プロジェクト名に合わせて変更

# Git設定（毎回実行で安全）
# !git config --global user.name "hiroki0427"
# !git config --global user.email "hiroki0427jp@icloud.com"

# コミット実行
print(f"💾 コミット中: {MESSAGE}")
# !git add .
# !git commit -m "{MESSAGE}"
# !git push origin main
print("✅ 完了!")
# Out:
# Mounted at /content/drive
# 💾 コミット中: initial commit
# [main d142a6c] initial commit
#  3 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 commit.ipynb
#  delete mode 100644 voice_synthesis/Untitled0.ipynb
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 4.00 KiB | 409.00 KiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/hiroki0427/DDSP_Application_Research.git
#    76bc57c..d142a6c  main -> main
# ✅ 完了!
