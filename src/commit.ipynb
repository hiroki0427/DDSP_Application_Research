# %%
# ========================================
# 💾 日常コミット用（これだけ実行すればOK）
# ========================================

# === 設定（ここだけ変更） ===
MESSAGE = "unique"  # ← ここだけ変更してください

# === 実行（変更不要） ===
import os
from google.colab import drive

# Google Drive マウント
drive.mount('/content/drive')

# プロジェクトフォルダに移動
os.chdir('/content/drive/MyDrive/hioki_lab')  # ← プロジェクト名に合わせて変更

# Git設定（毎回実行で安全）
# !git config --global user.name "hiroki0427"
# !git config --global user.email "hiroki0427jp@icloud.com"

# コミット実行
print(f"💾 コミット中: {MESSAGE}")
# !git add .
# !git commit -m "{MESSAGE}"
# !git push origin main
print("✅ 完了!")
# Out:
# Mounted at /content/drive
# 💾 コミット中: initial commit
# [main 346ad0e] initial commit
#  13 files changed, 3 insertions(+), 3 deletions(-)
#  delete mode 100644 commit.ipynb
#  create mode 100644 src/commit.ipynb
#  rename {mamba => src/mamba}/Untitled0.ipynb (100%)
#  rename {mamba => src/mamba}/mamba_try2_env_build.ipynb (100%)
#  rename {mamba => src/mamba}/mamba_try_1_kotomamba.ipynb (100%)
#  rename Untitled0.ipynb => src/option/initial_option.ipynb (100%)
#  create mode 100644 src/voice_synthesis/DDSP_Reproduction.ipynb
#  rename {voice_synthesis => src/voice_synthesis}/DDSP_Reproduction_harmony_only.ipynb (100%)
#  create mode 100644 src/voice_synthesis/DDSP_with_uniqueID.ipynb
#  rename {voice_synthesis => src/voice_synthesis}/READ_ME_DDSP_Reproduction.ipynb (100%)
#  rename {voice_synthesis => src/voice_synthesis}/tutorial.ipynb (100%)
#  delete mode 100644 voice_synthesis/DDSP_Reproduction.ipynb
#  delete mode 100644 voice_synthesis/DDSP_with_uniqueID.ipynb
# Enumerating objects: 12, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (11/11), 2.79 MiB | 3.42 MiB/s, done.
# Total 11 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/hiroki0427/DDSP_Application_Research.git
#    d142a6c..346ad0e  main -> main
# ✅ 完了!
